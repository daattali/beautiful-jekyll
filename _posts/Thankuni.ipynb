# %%
import os
import cv2
import numpy as np
import pandas as pd
from matplotlib import pyplot as plt
# %matplotlib inline

# %%
img_path = r'C:\Users\User\Desktop\Django\thankuni.jpg'

# %%
main_img = cv2.imread(img_path)
img = cv2.cvtColor(main_img, cv2.COLOR_BGR2RGB)
plt.imshow(img)

# %%
main_img.shape
# Out:
# (1442, 1482, 3)

# %%
resized_image = cv2.resize(img, (500,500))
plt.imshow(resized_image)

# %%
y,x,_ = img.shape

# %%
resized_image.shape
# Out:
# (500, 500, 3)

# %%
gs = cv2.cvtColor(resized_image,cv2.COLOR_RGB2GRAY)
plt.imshow(gs,cmap='gray')

# %%
blur = cv2.GaussianBlur(gs, (55,55),0)
plt.imshow(blur,cmap='gray')

# %%
ret_otsu,im_bw_otsu = cv2.threshold(gs,0,255,cv2.THRESH_BINARY_INV+cv2.THRESH_OTSU)
plt.imshow(im_bw_otsu,cmap='binary')

# %%
l = [16,9,23,0,13,16]

# %%
import statistics

# %%
l = [16,9,23,13,16]
l2 = statistics.mean(l)

# %%
l2
# Out:
# 15.4

# %%
l3 = statistics.median(l)

# %%
l3
# Out:
# 16

# %%
l4 = statistics.mode(l)

# %%
l4
# Out:
# 16
